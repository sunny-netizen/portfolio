# %%
import numpy as np
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

#Send a high resolution image (300 dpi) of your visualization and a description of no more than 150 words to nightingale@datavisualizationsociety.org by FEBRUARY 15, 2023. Submissions may be featured online or in print.

# %%
elements = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/bob-ross/elements-by-episode.csv')
elements.to_csv('hickey.csv', index=False)

colors = pd.read_csv('https://raw.githubusercontent.com/jwilber/Bob_Ross_Paintings/master/data/bob_ross_paintings.csv')
colors.to_csv('colors.csv', index=False)

# %%
elements.columns
colors.columns
# Out:
# Index(['EPISODE', 'TITLE', 'APPLE_FRAME', 'AURORA_BOREALIS', 'BARN', 'BEACH',
#        'BOAT', 'BRIDGE', 'BUILDING', 'BUSHES', 'CABIN', 'CACTUS',
#        'CIRCLE_FRAME', 'CIRRUS', 'CLIFF', 'CLOUDS', 'CONIFER', 'CUMULUS',
#        'DECIDUOUS', 'DIANE_ANDRE', 'DOCK', 'DOUBLE_OVAL_FRAME', 'FARM',
#        'FENCE', 'FIRE', 'FLORIDA_FRAME', 'FLOWERS', 'FOG', 'FRAMED', 'GRASS',
#        'GUEST', 'HALF_CIRCLE_FRAME', 'HALF_OVAL_FRAME', 'HILLS', 'LAKE',
#        'LAKES', 'LIGHTHOUSE', 'MILL', 'MOON', 'MOUNTAIN', 'MOUNTAINS', 'NIGHT',
#        'OCEAN', 'OVAL_FRAME', 'PALM_TREES', 'PATH', 'PERSON', 'PORTRAIT',
#        'RECTANGLE_3D_FRAME', 'RECTANGULAR_FRAME', 'RIVER', 'ROCKS',
#        'SEASHELL_FRAME', 'SNOW', 'SNOWY_MOUNTAIN', 'SPLIT_FRAME', 'STEVE_ROSS',
#        'STRUCTURE', 'SUN', 'TOMB_FRAME', 'TREE', 'TREES', 'TRIPLE_FRAME',
#        'WATERFALL', 'WAVES', 'WINDMILL', 'WINDOW_FRAME', 'WINTER',
#        'WOOD_FRAMED'],
#       dtype='object')

# %%
colors_sub = colors.loc[:, 'Black_Gesso':'Alizarin_Crimson'].values
colors_id = colors['painting_index'].values
elements_sub = elements.loc[:, 'APPLE_FRAME':'WOOD_FRAMED'].values
elements_id = elements['TITLE'].values

# %%
colors_sub.shape
colors_id.shape
# Out:
# (403,)

# %%
def cosine_distance_matrix (array, row_ids):

    # Initialize an array to store the cosine distances
    cosine_distances = np.zeros((array.shape[0], array.shape[0]))

    # Compute the cosine distance between every pair of rows
    for i in range(array.shape[0]):
        for j in range(array.shape[0]):
            cos_sim = np.dot(array[i], array[j]) / (np.linalg.norm(array[i]) * np.linalg.norm(array[j]))
            cos_dist = 1 - cos_sim
            cosine_distances[i, j] = cos_dist
    
    #Add the row IDs to the cosine distances array
    cosine_distances = pd.DataFrame(cosine_distances, index=row_ids, columns=row_ids)

    return cosine_distances

colors_cosine = cosine_distance_matrix(colors_sub, colors_id)
colors_cosine.head()
# Out:
#               282           283       284           285           286  \
# 282  2.220446e-16  2.220446e-16  0.057191  3.876276e-01  2.220446e-16
# 283  2.220446e-16  2.220446e-16  0.057191  3.876276e-01  2.220446e-16
# 284  5.719096e-02  5.719096e-02  0.000000  4.226497e-01  5.719096e-02
# 285  3.876276e-01  3.876276e-01  0.422650 -2.220446e-16  3.876276e-01
# 286  2.220446e-16  2.220446e-16  0.057191  3.876276e-01  2.220446e-16
#
#           287           288           289           290           291  ...  \
# 282  0.469670  2.220446e-16  2.220446e-16  2.220446e-16  2.220446e-16  ...
# 283  0.469670  2.220446e-16  2.220446e-16  2.220446e-16  2.220446e-16  ...
# 284  0.333333  5.719096e-02  5.719096e-02  5.719096e-02  5.719096e-02  ...
# 285  0.133975  3.876276e-01  3.876276e-01  3.876276e-01  3.876276e-01  ...
# 286  0.469670  2.220446e-16  2.220446e-16  2.220446e-16  2.220446e-16  ...
#
#           402       403       404       405       406       407       408  \
# ...

# %%
# Out:
#               282           283       284           285           286  \
# 282  2.220446e-16  2.220446e-16  0.057191  3.876276e-01  2.220446e-16
# 283  2.220446e-16  2.220446e-16  0.057191  3.876276e-01  2.220446e-16
# 284  5.719096e-02  5.719096e-02  0.000000  4.226497e-01  5.719096e-02
# 285  3.876276e-01  3.876276e-01  0.422650 -2.220446e-16  3.876276e-01
# 286  2.220446e-16  2.220446e-16  0.057191  3.876276e-01  2.220446e-16
# ..            ...           ...       ...           ...           ...
# 407  2.440711e-01  2.440711e-01  0.287303  5.370900e-01  2.440711e-01
# 408  4.116516e-01  4.116516e-01  0.352850  6.797437e-01  4.116516e-01
# 409  2.855655e-01  2.855655e-01  0.326425  5.000000e-01  2.855655e-01
# 410  4.654775e-01  4.654775e-01  0.496047  3.453463e-01  4.654775e-01
# 411  3.876276e-01  3.876276e-01  0.326425  6.666667e-01  3.876276e-01
#
#           287           288           289           290           291  ...  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [42], line 1
# ----> 1 cosine_distances.head()
#
# NameError: name 'cosine_distances' is not defined

# %%
hickey.head()
# Out:
#   EPISODE                  TITLE  APPLE_FRAME  AURORA_BOREALIS  BARN  BEACH  \
# 0  S01E01  "A WALK IN THE WOODS"            0                0     0      0
# 1  S01E02         "MT. MCKINLEY"            0                0     0      0
# 2  S01E03         "EBONY SUNSET"            0                0     0      0
# 3  S01E04          "WINTER MIST"            0                0     0      0
# 4  S01E05         "QUIET STREAM"            0                0     0      0
#
#    BOAT  BRIDGE  BUILDING  BUSHES  ...  TOMB_FRAME  TREE  TREES  TRIPLE_FRAME  \
# 0     0       0         0       1  ...           0     1      1             0
# 1     0       0         0       0  ...           0     1      1             0
# 2     0       0         0       0  ...           0     1      1             0
# 3     0       0         0       1  ...           0     1      1             0
# 4     0       0         0       0  ...           0     1      1             0
#
# ...
